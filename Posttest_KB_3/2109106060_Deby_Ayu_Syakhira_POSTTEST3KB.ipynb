# %% [markdown]
# ## __POSTTEST 3__
#
# #### Nama  : Deby Ayu Syakhira
# #### NIM   : 2109106060
# #### Kelas : Informatika B1 2021

# %% [markdown]
# ***

# %% [markdown]
# # Membaca data dari file CSV _heart_2020_cleaned_

# %%
import pandas as pd                                         #mengimpor library pandas
import matplotlib.pyplot as plt
import seaborn as sns                                       #mengimpor library numpy
dataFrame = pd.read_csv('heart_2020_cleaned.csv')           #membaca file CSV dengan nama 'heart_2020_cleaned.csv' dan disimpan di dalam variabel dataFrame
dataFrame
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %% [markdown]
# ***

# %% [markdown]
# # 1. GRAFIK BATANG

# %%
#menghitung jumlah data berdasarkan kategori usia dan mengurutkannya berdasarkan index
data = dataFrame['AgeCategory'].value_counts().sort_index()

#menghitung total jumlah data dalam dataset
total_data = len(dataFrame)

plt.figure(figsize = (12, 6)) #mengatur ukuran figure

#membuat grafik batang menggunakan Seaborn
gb = sns.barplot(x = data.index, y = data.values)

#membuat judul grafik dan label pada sumbu x dan y
plt.title('Distribusi Kategori Usia')
plt.xlabel('Kategori Usia')
plt.xticks(rotation = 45) #mengatur rotasi label sumbu x 
plt.ylabel('Jumlah')

#membuat label persentase setiap bar di grafik
#menggunakan perulangan untuk melalui setiap bar yang ada di grafik
for i in gb.patches:
    jdata = i.get_height() #mengambil tinggi (banyaknya) data dari setiap bar
    gb.annotate(f'{jdata/total_data:.2%}', (i.get_x() + i.get_width() / 2., jdata), ha = 'center', va = 'bottom')

plt.show()

# %% [markdown]
# ## Kesimpulan:
# Grafik di atas menggambarkan distribusi data berdasarkan kategori usia yang telah dikelompokkan berdasarkan rentang usia dari 18 hingga 80-an, dengan memperlihatkan jumlah dan persentase data yang ada dalam setiap kategori usia.
#
# - Usia 18-24 berjumlah 21064 atau 6.59% dari total data yang ada di dalam dataset.
# - Usia 25-29 berjumlah 16955 atau 5.30% dari total data yang ada di dalam dataset.
# - Usia 30-34 berjumlah 18753 atau 5.86% dari total data yang ada di dalam dataset.
# - Usia 35-39 berjumlah 20550 atau 6.43% dari total data yang ada di dalam dataset.
# - Usia 40-44 berjumlah 21006 atau 6.57% dari total data yang ada di dalam dataset.
# - Usia 45-49 berjumlah 21791 atau 6.81% dari total data yang ada di dalam dataset.
# - Usia 50-54 berjumlah 25382 atau 7.94% dari total data yang ada di dalam dataset.
# - Usia 55-59 berjumlah 29757 atau 9.31% dari total data yang ada di dalam dataset.
# - Usia 60-64 berjumlah 33686 atau 10.53% dari total data yang ada di dalam dataset.
# - Usia 65-69 berjumlah 34151 atau 10.68% dari total data yang ada di dalam dataset.
# - Usia 70-74 berjumlah 31065 atau 9.71% dari total data yang ada di dalam dataset.
# - Usia 75-79 berjumlah 21482 atau 6.72% dari total data yang ada di dalam dataset.
# - Usia 80-an berjumlah 24153 atau 7.55% dari total data yang ada di dalam dataset.

# %% [markdown]
# ***

# %% [markdown]
# # 2. GRAFIK PIE (PIE CHART)

# %%
#menghitung jumlah data berdasarkan kolom 'HeartDisease'
jumlah = dataFrame['HeartDisease'].value_counts()

#menentukan jarak potongan 'Yes' dari pusat pie chart
explode = [0.2, 0] 

#membuat pie chart 
plt.pie(jumlah, labels = ['No', 'Yes'], colors = ['blue', 'gold'], autopct = '%1.1f%%', startangle = 180, explode = explode, shadow = True)

#membuat judul pie chart
plt.title('Jumlah Orang dengan dan tanpa Penyakit Jantung')

#membuat lebel legend di luar pie chart
labels = ['Tidak Punya Penyakit Jantung', 'Punya Penyakit Jantung']
plt.legend(labels, bbox_to_anchor = (1.5, 0.9))
plt.axis('equal') #memastikan  skala sumbu x dan y pada plot sama 


plt.show()

# %% [markdown]
# ## Kesimpulan:
# - Grafik pie di atas menggambarkan jumlah orang yang memiliki dan tidak memiliki penyakit jantung.
# - Potongan "No" menunjukkan jumlah orang yang tidak memiliki penyakit jantung,
# - Sedangkan potongan "Yes" menunjukkan jumlah orang yang memiliki penyakit jantung.
# - Dari grafik di atas dapat dilihat sebanyak 91.4% orang yang tidak memiliki penyakit jantung dan 8.6% orang yang memiliki penyakit jantung.

# %% [markdown]
# ***

# %% [markdown]
# # 3. HISTOGRAM

# %%
#membuat variabel 'kolom' yang berisi daftar kolom yang akan digunakan untuk membuat histogram
kolom = ['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']

#membuat subplot dengan ukuran 2x2 dan mengatur ukuran figure
fig, gh = plt.subplots(2, 2, figsize = (12, 8))
fig.suptitle('Distribusi Data dengan Histogram: BMI, Physical Health, Mental Health, dan Sleep Time') #membuat judul figure

#menggunakan perulangan untuk membuat 4 subplot histogram, serta menambahkan garis rata-rata serta median
for i, column in enumerate(kolom):
    plt.subplot(2, 2, i + 1) #memilih subplot
    sns.histplot(dataFrame[column], bins=15, color = 'green') #membuat histogram dengan seaborn

    #menghitung nilai rata-rata dari data sesuai kolom dan menambahkan garis rata-rata pada histogram
    mean = dataFrame[column].mean()
    plt.axvline(mean, color = 'red', linestyle = 'solid', linewidth = 2, label = f'Rata-rata: {mean:.2f}')

    #menghitung nilai median dari data sesuai kolom dan menambahkan garis median pada histogram
    median = dataFrame[column].median()
    plt.axvline(median, color = 'yellow', linestyle = 'solid', linewidth = 2, label = f'Median: {median:.2f}')
    
    plt.title(f'{column}') #membuat judul subplot
    #membuat lebel pada sumbu x dan y
    plt.ylabel('Frekuensi kemunculan')
    plt.xlabel(column)
    #membuat lebel legend di luar histogram
    plt.legend()

plt.tight_layout() #mengatur tata letak subplot
plt.show()

# %% [markdown]
# ## Kesimpulan:
# - Grafik histogram di atas memvisualisasikan distribusi data dari empat kolom berbeda dalam satu gambar.
# - Setiap subplot histogram menggambarkan distribusi data dari kolom yang berbeda, yaitu 'BMI', 'PhysicalHealth', 'MentalHealth', dan 'SleepTime'.
# - Subplot pertama menggambarkan distribusi data dari kolom 'BMI'. Pada histogram ini, kita dapat melihat frekuensi kemunculan berbagai nilai BMI dari dataset. Rata-rata (mean) dari kolom 'BMI' ditandai dengan garis vertikal merah yang terletak pada nilai 28,33 pada sumbu x. Sementara itu, Nilai tengah (median) dari kolom 'BMI' ditandai dengan garis vertikal kuning yang terletak pada nilai 27,34 pada sumbu x.
# - Subplot kedua menggambarkan distribusi data dari kolom 'PhysicalHealth'. Pada histogram ini, kita dapat melihat frekuensi kemunculan berbagai nilai PhysicalHealth dari dataset. Rata-rata (mean) dari kolom 'PhysicalHealth' ditandai dengan garis vertikal merah yang terletak pada nilai 3,37 pada sumbu x. Sementara itu, Nilai tengah (median) dari kolom 'PhysicalHealth' ditandai dengan garis vertikal kuning yang terletak pada nilai 0 pada sumbu x.
# - Subplot ketiga menggambarkan distribusi data dari kolom 'MentalHealth'. Pada histogram ini, kita dapat melihat frekuensi kemunculan berbagai nilai MentalHealth dari dataset. Rata-rata (mean) dari kolom 'MentalHealth' ditandai dengan garis vertikal merah yang terletak pada nilai 3,90 pada sumbu x. Sementara itu, Nilai tengah (median) dari kolom 'MentalHealth' ditandai dengan garis vertikal kuning yang terletak pada nilai 0 pada sumbu x.
# - Subplot keempat menggambarkan distribusi data dari kolom 'SleepTime'. Pada histogram ini, kita dapat melihat frekuensi kemunculan berbagai nilai SleepTime dari dataset. Rata-rata (mean) dari kolom 'SleepTime' ditandai dengan garis vertikal merah yang terletak pada nilai 7,10 pada sumbu x. Sementara itu, Nilai tengah (median) dari kolom 'SleepTime' ditandai dengan garis vertikal kuning yang terletak pada nilai 7,00 pada sumbu x.

# %% [markdown]
# ***

# %% [markdown]
# # 4. BOX PLOT

# %%
plt.figure(figsize=(12, 6)) #mengatur ukuran figure

#membuat box plot berdasarkan kolom 'BMI', 'PhysicalHealth', 'MentalHealth', dan 'SleepTime' menggunakan Seaborn
sns.boxplot(dataFrame [['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']])

#membuat judul box plot
plt.title('Distribusi Nilai pada Kolom BMI, Physical Health, Mental Health, dan Sleep Time')
plt.ylabel('Nilai')
plt.show()

# %% [markdown]
# ## Kesimpulan:
# -  Grafik di atas memvisualisasikan distribusi data dalam empat kolom yang berbeda, yaitu BMI, Physical Health, Mental Health, dan Sleep Time.
# -  Box plot pada kolom 'BMI' menggambarkan distribusi berat badan indeks (BMI) dari individu dalam dataset.
#     * Terdapat nilai Minimum dan Maximum dalam kolom 'BMI'
#     * Garis tengah kotak menunjukkan nilai tengah (median) BMI di antara semua individu.
#     * Terdapat Kuartil Pertama (Q1) dan Kuartil Ketiga (Q3).
#     * Terdapat beberapa outlier di atas Q1 yang menunjukkan adanya individu dengan BMI yang tinggi dan beberapa outlier di bawah Q3 yang menujukkan adanya individu dengan BMI yang rendah.
# - Box plot pada kolom 'PhysicalHealth' menggambarkan distribusi data Physical Health dari individu dalam dataset.
#   * Terdapat nilai Minimum dan Maximum dalam kolom 'PhysicalHealth'
#   * Garis tengah kotak menunjukkan nilai tengah (median) Physical Health di antara semua individu. karena median dari kolom Physical Health itu 0, maka garisnya berada pada nilai 0, sama seperti Q3.
#   * Terdapat Kuartil Pertama (Q1) dan Kuartil Ketiga (Q3).
#   * Terdapat beberapa outlier di atas Q1 yang menunjukkan adanya individu dengan Physical Health yang tinggi.
# - Box plot pada kolom 'MentalHealth' menggambarkan distribusi data Mental Health dari individu dalam dataset.
#   * Terdapat nilai Minimum dan Maximum dalam kolom 'MentalHealth'
#   * Garis tengah kotak menunjukkan nilai tengah (median) Mental Health di antara semua individu. karena median dari kolom Mental Health itu 0, maka garisnya berada pada nilai 0, sama seperti Q3.
#   * Terdapat Kuartil Pertama (Q1) dan Kuartil Ketiga (Q3).
#   * Terdapat beberapa outlier di atas Q1 yang menunjukkan adanya individu dengan Mental Health yang tinggi.
# - Box plot pada kolom 'SleepTime' menggambarkan distribusi data Sleep Time dari individu dalam dataset.
#   * Terdapat nilai Minimum dan Maximum dalam kolom 'SleepTime'
#   * Garis tengah kotak menunjukkan nilai tengah (median)  Sleep Time di antara semua individu.
#   * Terdapat Kuartil Pertama (Q1) dan Kuartil Ketiga (Q3).
#   * Terdapat beberapa outlier di atas Q1 yang menunjukkan adanya individu dengan  Sleep Time yang tinggi dan beberapa outlier di bawah Q3 yang menujukkan adanya individu dengan BMI yang rendah.*

# %% [markdown]
# ***

# %% [markdown]
# # 5. LINE PLOT

# %%
#membuat variable 'kel_usia' yang berisi data yang dikelompokkan berdasarkan 'AgeCategory',lalu menghitung rata-rata BMI untuk setiap kelompok usia
kel_usia = dataFrame.groupby('AgeCategory')['BMI'].mean()

plt.figure(figsize=(12, 6)) #mengatur ukuran figure

#membuat line plot dengan menggunakan data rata-rata BMI
plt.plot(kel_usia.index, kel_usia.values, marker='o', linestyle='-', color='gold', label='Rata-rata BMI')

#membuat judul grafik dan label pada sumbu x dan y
plt.title('Distribusi Rata-rata BMI berdasarkan Usia')
plt.xlabel('Usia (AgeCategory)')
plt.ylabel('Rata-rata BMI')

#memberikan nilai rata-rata BMI pada titik-titik di grafik
for i, value in enumerate(kel_usia.values):
    plt.text(kel_usia.index[i], value, f'{value:.2f}', ha='center', va='bottom', fontsize=10)

plt.grid(True) #menambahkan grid pada grafik
plt.legend() #membuat label legend pada grafik
plt.show()

# %% [markdown]
# ## Kesimpulan:
# - Grafik Line di atas menggambarkan distribusi rata-rata Indeks Massa Tubuh (BMI) berdasarkan kelompok usia ('AgeCategory').
# - Garis plot menghubungkan titik-titik yang mewakili rata-rata BMI untuk setiap kelompok usia.
# - Nilai rata-rata BMI ditambahkan pada setiap titik di grafik untuk memberikan informasi lebih lanjut tentang nilai-nilai ini di setiap kelompok usia.
#    * Rata-rata Indeks Massa Tubuh (BMI) pada rentang usia 18-24, yaitu 25,76.
#    * Rata-rata Indeks Massa Tubuh (BMI) pada rentang usia 25-29, yaitu 27,69.
#    * Rata-rata Indeks Massa Tubuh (BMI) pada rentang usia 30-34, yaitu 28,44.
#    * Rata-rata Indeks Massa Tubuh (BMI) pada rentang usia 35-39, yaitu 28,84.
#    * Rata-rata Indeks Massa Tubuh (BMI) pada rentang usia 40-44, yaitu 29,20.
#    * Rata-rata Indeks Massa Tubuh (BMI) pada rentang usia 45-49, yaitu 29,49.
#    * Rata-rata Indeks Massa Tubuh (BMI) pada rentang usia 50-54, yaitu 29,43.
#    * Rata-rata Indeks Massa Tubuh (BMI) pada rentang usia 55-59, yaitu 29,10.
#    * Rata-rata Indeks Massa Tubuh (BMI) pada rentang usia 60-64, yaitu 28,82.
#    * Rata-rata Indeks Massa Tubuh (BMI) pada rentang usia 65-69, yaitu 28.67.
#    * Rata-rata Indeks Massa Tubuh (BMI) pada rentang usia 70-74, yaitu 28,18.
#    * Rata-rata Indeks Massa Tubuh (BMI) pada rentang usia 75-79, yaitu 27.60.
#    * Rata-rata Indeks Massa Tubuh (BMI) pada rentang usia 80-an, yaitu 26.22.
# - Grafik di atas membantu dalam memvisualisasikan hubungan antara usia dan rata-rata BMI dalam dataset. Hal ini mempermudah kita untuk melihat adanya pola dalam data serta mengenali perbedaan nilai rata-rata BMI antara kelompok usia yang berbeda.

# %% [markdown]
# ***

# %% [markdown]
# # 6. HEATMAP

# %%
#membuat variabel 'data' yang berisi daftar kolom yang akan digunakan untuk membuat heatmap
data = ['BMI', 'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'AgeCategory', 'PhysicalActivity', 'SleepTime']
plt.figure(figsize=(5, 5)) #mengatur ukuran figure
matriks_corr = dataFrame[data].corr()#menghitung matriks korelasi antar kolom-kolom yang dipilih

#membuat heatmap
sns.heatmap(matriks_corr,  cmap='coolwarm', annot=True, linewidths=.5, center=0)

plt.title('Korelasi Antar Kolom')#membuat judul
plt.show()

# %% [markdown]
# ## Kesimpulan:
# - Grafik di atas memberikan gambaran visual mengenai hubungan antara kolom BMI, PhysicalHealth, MentalHealth, dan SleepTime dalam dataset.
#   * Pada grafik, Korelasi antara BMI dan PhysicalHealth sebesar 0.11 artinya ada korelasi positif antara kedua kolom.
#   * Pada grafik, Korelasi antara BMI dan MentalHealth sebesar 0.064 artinya ada korelasi positif antara kedua kolom.
#   * Pada grafik, Korelasi antara BMI dan SleepTime sebesar -0.052 artinya ada korelasi negatif antara kedua kolom.
#   * Pada grafik, Korelasi antara PhysicalHealth dan MentalHealth sebesar 0.29 artinya ada korelasi positif antara kedua kolom.
#   * Pada grafik, Korelasi antara PhysicalHealth dan SleepTime sebesar -0.061 artinya ada korelasi negatif antara kedua kolom.
#   * Pada grafik, Korelasi antara MentalHealth dan SleepTime sebesar -0.12 artinya ada korelasi negatif antara kedua kolom.
