# %% [markdown]
# ## __POSTTEST 4__
#
# #### Nama  : Deby Ayu Syakhira
# #### NIM   : 2109106060
# #### Kelas : Informatika B1 2021

# %% [markdown]
# ***

# %% [markdown]
# # Membaca data dari file CSV _heart_2020_cleaned_

# %%
import pandas as pd                                              #mengimpor library pandas
import numpy as np                                               #mengimpor library numpy
from sklearn.model_selection import train_test_split             #mengimpor train_test_split dari library sklearn.model_selection
from sklearn.preprocessing import MinMaxScaler                   #mengimpor MinMaxScaler dari library sklearn.preprocessing
from sklearn.preprocessing import StandardScaler                 #mengimpor StandardScaler dari library sklearn.preprocessing
from sklearn.impute import SimpleImputer                         #mengimpor SimpleImputer dari library sklearn.impute
from sklearn.preprocessing import OneHotEncoder                  #mengimpor OneHotEncoder dari library sklearn.preprocessing
dataFrame = pd.read_csv('heart_2020_cleaned.csv')                #membaca file CSV dengan nama 'heart_2020_cleaned.csv' dan disimpan di dalam variabel dataFrame
dataFrame
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %% [markdown]
# ***

# %% [markdown]
# 1. __Membagi dataset menjadi training set dan testing set dengan proporsi 70:30__

# %%
x = dataFrame.iloc[:,1:] #mengambil semua kolom kecuali kolom pertama dan menyimpannya dalam variabel x
y = dataFrame.loc[:,'HeartDisease'] #mengambil kolom 'HeartDisease' dan menyimpannya dalam variabel y


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3) #memisahkan data menjadi training set (70%) dan testing set (30%)
print("|=======================|")
print("|   PEMBAGIAN DATASET   |")
print("|=======================|")
print("|X_train :", x_train.shape, "|") #menampilkan dimensi x_train
print("|X_test  :", x_test.shape, " |")   #menampilkan dimensi x_test
print("|y_train :", y_train.shape, "   |") #menampilkan dimensi y_train
print("|y_test  :", y_test.shape, "    |")  #menampilkan dimensi y_test
print("|=======================|")
# Out:
# |=======================|
# |   PEMBAGIAN DATASET   |
# |=======================|
# |X_train : (223856, 17) |
# |X_test  : (95939, 17)  |
# |y_train : (223856,)    |
# |y_test  : (95939,)     |
# |=======================|

# %% [markdown]
# ***

# %% [markdown]
# 2. __Melakukan normalisasi data pada salah satu attribute, yaitu pada atribut 'BMI' menggunakan Min Max scaler__

# %%
copydata = dataFrame.copy() #copy dataFrame

mms = MinMaxScaler() #membuat objek MinMaxScaler

attribute  = 'BMI' #menentukan atribut yang akan dinormalisasi (BMI)
copydata[attribute] = mms.fit_transform(copydata[[attribute]]) #proses normalisasi

copydata['BMI'] = copydata['BMI'].round(2) #membulatkan nilai dari kolom 'BMI' menjadi 2 desimal

#menampilkan data yang sudah dinormalisasi
print("================================================================================")
print("|             MENAMPILKAN DATA SETELAH MELAKUKAN NORMALISASI                   |")
print("================================================================================")
print(copydata)
#menampilkan nilai minimum dan maksimum dari kolom 'BMI' setelah dinormalisasi
print("|==============================================================================|")
print("|          MENAMPILKAN NILAI MIN & MAX SETELAH MELAKUKAN NORMALISASI           |")
print("|==============================================================================|")
print("|Nilai Minimum  : {:.1f}                                                          |".format(copydata[attribute].min()))
print("|Nilai Maksimum : {:.1f}                                                          |".format(copydata[attribute].max()))
print("|==============================================================================|")
# Out:
# ...
# |             MENAMPILKAN DATA SETELAH MELAKUKAN NORMALISASI                   |
# ...
#        HeartDisease   BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  0.06     Yes              No     No             3.0
# 1                No  0.10      No              No    Yes             0.0
# 2                No  0.18     Yes              No     No            20.0
# 3                No  0.15      No              No     No             0.0
# 4                No  0.14      No              No     No            28.0
# ...             ...   ...     ...             ...    ...             ...
# 319790          Yes  0.19     Yes              No     No             7.0
# 319791           No  0.22     Yes              No     No             0.0
# 319792           No  0.15      No              No     No             0.0
# 319793           No  0.25      No              No     No             0.0
# 319794           No  0.42      No              No     No             0.0
#
# ...

# %% [markdown]
# ***

# %% [markdown]
# 3. __Melakukan standarisasi pada dataset__

# %%
cdata = dataFrame.copy() #copy dataFrame

cNumerik = ['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime'] #menentukan kolom numerik yang akan distandarisasi

ss = StandardScaler() #membuat objek StandardScaler
scdata = ss.fit_transform(cdata[cNumerik]) #proses standarisasi

#menampilkan data, standar deviasi dan nilai rata-rata sebelum melakukan standarisasi
print("================================================================================")
print("|             MENAMPILKAN DATA SEBELUM MELAKUKAN STANDARISASI                  |")
print("================================================================================")
print(cdata[cNumerik])

print("\n=============================")
print("|   STANDAR DEVIASI DATA    |")
print("=============================")
print(cdata[cNumerik].std().round(1))
print("\n=============================")
print("|      RATA-RATA DATA       |")
print("=============================")
print(cdata[cNumerik].mean().round(1))

#menampilkan data, standar deviasi dan nilai rata-rata setalah melakukan standarisasi
print("================================================================================")
print("|             MENAMPILKAN DATA SETELAH MELAKUKAN STANDARISASI                  |")
print("================================================================================")
print(pd.DataFrame(scdata, columns=cNumerik))
print("\n=============================")
print("|   STANDAR DEVIASI DATA    |")
print("=============================")
print(pd.DataFrame(scdata, columns=cNumerik).std().round(1))
print("\n=============================")
print("|      RATA-RATA DATA       |")
print("=============================")
print(pd.DataFrame(scdata, columns=cNumerik).mean().round(1))
# Out:
# ...
# |             MENAMPILKAN DATA SEBELUM MELAKUKAN STANDARISASI                  |
# ...
#           BMI  PhysicalHealth  MentalHealth  SleepTime
# 0       16.60             3.0          30.0        5.0
# 1       20.34             0.0           0.0        7.0
# 2       26.58            20.0          30.0        8.0
# 3       24.21             0.0           0.0        6.0
# 4       23.71            28.0           0.0        8.0
# ...       ...             ...           ...        ...
# 319790  27.41             7.0           0.0        6.0
# 319791  29.84             0.0           0.0        5.0
# 319792  24.24             0.0           0.0        6.0
# 319793  32.81             0.0           0.0       12.0
# 319794  46.56             0.0           0.0        8.0
#
# [319795 rows x 4 columns]
#
# ...
# |   STANDAR DEVIASI DATA    |
# ...
# BMI               6.4
# PhysicalHealth    8.0
# MentalHealth      8.0
# SleepTime         1.4
# dtype: float64
#
# ...
# |      RATA-RATA DATA       |
# ...

# %% [markdown]
# ***

# %% [markdown]
# 4. __Melakukan Data cleaning pada Data dengan nilai null__

# %% [markdown]
# - __Mengecek apakah ada nilai null di dalam dataset__

# %%
dataFrame.isna().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %% [markdown]
# - __Karena dataset tidak memiliki nilai null, maka langkah selanjutnya yaitu membuat dataset agar memiliki nilai null__

# %%
kolom = ['Smoking', 'AlcoholDrinking', 'MentalHealth', 'SleepTime' ] #menentukan kolom yang akan diubah nilainya menjadi Null secara acak

probability = 0.5 #menentukan probabilitas munculnya nilai null setiap kolom, yaitu 50%

#menggunakan perulangan untuk menjelajahi setiap baris
for baris in range(len(dataFrame)):
    #memilih secara acak salah satu dari kolom yang sudah ditentukan sebelumnya
    kol = np.random.choice(kolom)
    #memeriksa apakah nilai acak kurang dari probabilitas yang telah ditentukan
    if np.random.rand() < probability:
        #jika ya, maka nilai di kolom tersebut diubah menjadi None (Null)
        dataFrame.at[baris, kol] = None

print(dataFrame) #menampilkan data yang sudah memiliki nilai null
print(dataFrame.isna().sum()) #menampilkan jumlah nilai null di setiap kolom
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %% [markdown]
# - __Mengganti nilai null sesuai dengan ketentuan__

# %%
imputers = {} #membuat dictionary kosong untuk menyimpan imputers

#menggunakan perulangan untuk menjelajahi setiap kolom
for kol in kolom:
    #jika tipe data kolom adalah 'object', akan mengisi nilai yang Null dengan 'Unknown'
    if dataFrame[kol].dtype == 'object':
        dataFrame[kol].fillna('Unknown', inplace=True)
    #jika tipe data kolom adalah 'int64', akan mengisi nilai yang Null menggunakan SimpleImputer dengan strategi 'mean'
    elif dataFrame[kol].dtype == 'int64':
        imputer = SimpleImputer(strategy = 'mean')
        dataFrame[kol] = imputer.fit_transform(dataFrame[[kol]])
    #jika tipe data kolom adalah 'float64', akan mengisi nilai yang Null menggunakan SimpleImputer dengan strategi 'median'
    elif dataFrame[kol].dtype == 'float64':
        imputer = SimpleImputer(strategy = 'median')
        dataFrame[kol] = imputer.fit_transform(dataFrame[[kol]])

#menampilkan data setelah melakukan subtitusi nilai Null
print(dataFrame)
print(dataFrame.isna().sum())
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %% [markdown]
# ***

# %% [markdown]
# 5. __Melakukan Data cleaning pada data dengan nilai duplikat__

# %%
dataFrame.duplicated().sum() #menghitung jumlah data yang duplikat
# Out:
# 14328

# %%
dataFrame.drop_duplicates(inplace =True) #menghapus data yang duplikat
dataFrame.duplicated().sum() #memeriksa jumlah data yang duplikat sudah terhapus atau belum
# Out:
# 0

# %% [markdown]
# ***

# %% [markdown]
# 6. __Mengganti tipe data dari salah satu attribute angka__

# %%
before = dataFrame['BMI'].dtype #memeriksa tipe data awal dari kolom 'BMI'
print("|==============================================================================|")
print("|Tipe data awal dari Attribute 'BMI':", before,"                                  |")

dataFrame['BMI'] = CDATA['BMI'].astype(np.int64) #mengubah tipe data kolom 'BMI' menjadi int64

#memeriksa tipe data dari kolom 'BMI' setelah perubahan
after = dataFrame['BMI'].dtype
print("|Tipe data setelah perubahan Attribute 'BMI':", after,"                            |")
print("|==============================================================================|")
#menampilkan data setelah perubahan
print(dataFrame)
# Out:
# |==============================================================================|
# |Tipe data awal dari Attribute 'BMI': float64                                  |
# |Tipe data setelah perubahan Attribute 'BMI': int64                            |
# |==============================================================================|
#        HeartDisease  BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No   16     Yes              No     No             3.0
# 1                No   20      No              No    Yes             0.0
# 2                No   26     Yes              No     No            20.0
# 3                No   24      No              No     No             0.0
# 4                No   23      No              No     No            28.0
# ...             ...  ...     ...             ...    ...             ...
# 319790          Yes   27     Yes              No     No             7.0
# ...

# %% [markdown]
# ***

# %% [markdown]
# 7. __Melakukan one hot encoding pada dataset__

# %%
encoded = pd.get_dummies(dataFrame[['Sex']]) #menggunakan 'pd.get_dummies' untuk membuat kolom baru berdasarkan kategori dalam kolom 'Sex'
dataFrame = dataFrame.drop('Sex', axis = 1) #menghapus kolom 'Sex' dari data yang asli
df = dataFrame.join(encoded) #menggabungkan data asli dengan data hasil onehot encoding

df['Sex'] = df['Sex_Female'].fillna(df['Sex_Male']) #mengisi kolom 'Sex' 

df.drop(['Sex_Male', 'Sex_Female'], axis = 1, inplace = True) #menghapus kolom 'Sex_Male" dan 'Sex_Female'

columns = df.columns.tolist()
columns.insert(columns.index('AgeCategory'), columns.pop(columns.index('Sex'))) #memindahkan kolom 'Sex' ke posisi setelah kolom 'AgeCategory' (Biar sama seperti data yang asli)
df = df[columns] #mengganti urutan kolom sesuai dengan yang telah ditentukan sebelumnya
df #menampilkan data setalah melakukan onehot encoding
# Out:
#        HeartDisease  BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No   16     Yes              No     No             3.0
# 1                No   20      No              No    Yes             0.0
# 2                No   26     Yes              No     No            20.0
# 3                No   24      No              No     No             0.0
# 4                No   23      No              No     No            28.0
# ...             ...  ...     ...             ...    ...             ...
# 319790          Yes   27     Yes              No     No             7.0
# 319791           No   29     Yes              No     No             0.0
# 319792           No   24      No              No     No             0.0
# 319793           No   32      No              No     No             0.0
# 319794           No   46      No              No     No             0.0
#
#         MentalHealth DiffWalking  Sex  AgeCategory      Race Diabetic  \
# ...

# %% [markdown]
# ***
